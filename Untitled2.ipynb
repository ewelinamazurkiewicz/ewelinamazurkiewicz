# %% [markdown]
# <a href="https://colab.research.google.com/github/ewelinamazurkiewicz/ewelinamazurkiewicz/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import glob
import os

# %%
test = pd.read_csv(r'C:\Users\Mazur&Ewela\Downloads\crime.csv',encoding="utf8")

# %%
print(test.duplicated(subset=['incident_id']).sum())

# %%
print(test.duplicated().sum())
